# %%
import plotly.express as px
import panel as pn
import pandas as pd
import os
from pathlib import Path

# %%
# Read in data
infsentiment_df = pd.read_csv("inf_sentiment_btc.csv")
infsentiment_df = infsentiment_df[['Date','Close','textblob','vader_compound','text','tweet_id']]
infsentiment_df
# Out:
#            Date    Close  textblob  vader_compound  \
# 0    2018-01-18  11045.0  0.200000        0.510600
# 1    2018-01-19  11476.0  0.312500        0.359500
# 2    2018-01-20  12728.0  0.500000        0.510600
# 3    2018-01-22  10771.0  0.050000        0.636900
# 4    2018-01-24  11414.0 -0.600000       -0.743000
# ..          ...      ...       ...             ...
# 677  2021-01-11  35476.0  0.425000        0.241700
# 678  2021-01-12  34103.0  0.028030        0.246300
# 679  2021-01-13  37375.0  0.179667        0.299950
# 680  2021-01-14  39170.0  0.146454        0.097633
# 681  2021-01-15  38856.0  0.072212        0.283757
#
#                                                   text  tweet_id
# 0    BTC = central economic planning.\nBCH = the fr...         1
# 1    I came to Bitcoin because I was a voluntaryist...         1
# 2    We discuss Bitcoin Cash and the forthcoming se...         1
# 3    Scaling Bitcoin on chain is an ultimate long t...         1
# ...

# %%
infsentiment_df.describe()
# Out:
#               Close    textblob  vader_compound    tweet_id
# count    682.000000  682.000000      682.000000  682.000000
# mean    9859.918328    0.145012        0.217136    2.306452
# std     5639.204748    0.195651        0.367003    2.487251
# min     3282.800000   -0.600000       -0.973800    1.000000
# 25%     6758.075000    0.000000        0.000000    1.000000
# 50%     8884.950000    0.123815        0.241950    1.000000
# 75%    10747.500000    0.236624        0.458500    3.000000
# max    40509.000000    1.000000        0.962700   20.000000

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces

fig.add_trace(
    go.Scatter(x=infsentiment_df.Date, y=infsentiment_df.Close, name="BTC close price",line=dict(color="#00e600")),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=infsentiment_df.Date, y=infsentiment_df.vader_compound, name="vader sentiment",line=dict(color=" #b3c6ff")),
    secondary_y=False,
)


fig.add_trace(
    go.Scatter(x=infsentiment_df.Date, y=infsentiment_df.textblob, name="textblob sentiment",line=dict(color="#0000b3")),
    secondary_y=False,
)


# Add figure title
fig.update_layout(
    title_text="Twitter Influencer sentiment and BTC close price"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> Sentiment scores", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> BTC Close price", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="4f0cee1a-316b-4774-b69d-cc3baf364d01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4f0cee1a-316b-4774-b69d-cc3baf364d01")) {                    Plotly.newPlot(                        "4f0cee1a-316b-4774-b69d-cc3baf364d01",                        [{"line": {"color": "#00e600"}, "name": "BTC close price", "type": "scatter", "x": ["2018-01-18", "2018-01-19", "2018-01-20", "2018-01-22", "2018-01-24", "2018-01-28", "2018-02-02", "2018-02-03", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-10", "2018-02-11", "2018-02-13", "2018-02-14", "2018-02-19", "2018-02-22", "2018-02-28", "2018-03-01", "2018-03-03", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-12", "2018-
# ...

# %%
#Different Method. @Manny you can ignore this the section below. this was me trying out other stuff

# Read scaled data
infsentiment_scaleddf = pd.read_csv("inf_sentiment_scaled.csv")
infsentiment_scaleddf = infsentiment_scaleddf[['Date','Close', 'textblob','vader_compound','text','tweet_id']]
infsentiment_scaleddf
# Out:
#            Date     Close  textblob  vader_compound  \
# 0    2018-01-18  0.208514  0.500000        0.766538
# 1    2018-01-19  0.220092  0.570312        0.688510
# 2    2018-01-20  0.253725  0.687500        0.766538
# 3    2018-01-22  0.201154  0.406250        0.831758
# 4    2018-01-24  0.218427  0.000000        0.119184
# ..          ...       ...       ...             ...
# 677  2021-01-11  0.864800  0.640625        0.627679
# 678  2021-01-12  0.827917  0.392519        0.630054
# 679  2021-01-13  0.915812  0.487292        0.657759
# 680  2021-01-14  0.964031  0.466534        0.553283
# 681  2021-01-15  0.955596  0.420132        0.649397
#
#                                                   text  tweet_id
# 0    BTC = central economic planning.\nBCH = the fr...         1
# 1    I came to Bitcoin because I was a voluntaryist...         1
# 2    We discuss Bitcoin Cash and the forthcoming se...         1
# 3    Scaling Bitcoin on chain is an ultimate long t...         1
# ...

# %%
# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces


fig.add_trace(
    go.Scatter(x=infsentiment_scaleddf.Date, y=infsentiment_scaleddf.vader_compound, name="vader sentiment"),
    secondary_y=False,
)


fig.add_trace(
    go.Scatter(x=infsentiment_scaleddf.Date, y=infsentiment_scaleddf.textblob, name="textblob sentiment",line=dict(color="#AB63FA")),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(x=infsentiment_scaleddf.Date, y=infsentiment_scaleddf.Close, name="BTC close price"),
    secondary_y=False,
)

# Add figure title
fig.update_layout(
    title_text="Twitter Influencer sentiment and BTC close price"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> BTC close price", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> Vader sentiment compound", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="b3b685f8-917d-4769-abc6-fbb05013b687" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3b685f8-917d-4769-abc6-fbb05013b687")) {                    Plotly.newPlot(                        "b3b685f8-917d-4769-abc6-fbb05013b687",                        [{"name": "vader sentiment", "type": "scatter", "x": ["2018-01-18", "2018-01-19", "2018-01-20", "2018-01-22", "2018-01-24", "2018-01-28", "2018-02-02", "2018-02-03", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-10", "2018-02-11", "2018-02-13", "2018-02-14", "2018-02-19", "2018-02-22", "2018-02-28", "2018-03-01", "2018-03-03", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-12", "2018-03-18", "2018-03-20", "2018-03
# ...

# %% [markdown]
# #
