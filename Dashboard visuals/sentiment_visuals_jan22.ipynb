# %%
import plotly.express as px
import panel as pn
import pandas as pd
import os
from pathlib import Path

# %%
# Read in Influencer data
influencer_sentiment = pd.read_csv("inf_sentiment_btc.csv")
influencer_sentiment = influencer_sentiment[['Date','Close','textblob','vader_compound','text','tweet_id']]

# %%
influencer_sentiment.describe()

# tweet_id is the count of tweets per day
# note that the count of tweets has decreased because we combined the tweets to get the average sentiment per day.
# this means we have 682 days of historical data
# Out:
#               Close    textblob  vader_compound    tweet_id
# count    706.000000  706.000000      706.000000  706.000000
# mean    9793.471388    0.146266        0.217224    2.623229
# std     5587.992770    0.194271        0.359299    2.964992
# min     3282.800000   -0.600000       -0.973800    1.000000
# 25%     6717.425000    0.000000        0.000000    1.000000
# 50%     8870.600000    0.125000        0.229425    1.000000
# 75%    10743.750000    0.236094        0.448025    3.000000
# max    40509.000000    1.000000        0.962700   24.000000

# %%
# Read in News data
news_sentiment = pd.read_csv("news_sentiment_btc.csv")
news_sentiment = news_sentiment[['Date','Close','textblob','vader_compound','text','tweet_id']]

# %%
news_sentiment.describe()
# Out:
#               Close    textblob  vader_compound    tweet_id
# count    810.000000  810.000000      810.000000  810.000000
# mean    9616.861852    0.072039        0.059186    7.562963
# std     5222.818744    0.129991        0.216534   11.763496
# min     3282.800000   -0.700000       -0.828600    1.000000
# 25%     6971.325000    0.000000       -0.034006    2.000000
# 50%     8751.450000    0.069634        0.059217    4.000000
# 75%    10317.750000    0.136014        0.173575    8.000000
# max    40509.000000    0.687500        0.840200  108.000000

# %%
# Graph on Influencer Sentiment against BTC price

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces

fig.add_trace(
    go.Scatter(x=influencer_sentiment.Date, y=influencer_sentiment.Close, name="BTC close price",line=dict(color="#00e600")),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=influencer_sentiment.Date, y=influencer_sentiment.vader_compound, name="vader sentiment",line=dict(color=" #b3c6ff")),
    secondary_y=False,
)


fig.add_trace(
    go.Scatter(x=influencer_sentiment.Date, y=influencer_sentiment.textblob, name="textblob sentiment",line=dict(color="#0000b3")),
    secondary_y=False,
)


# Add figure title
fig.update_layout(
    title_text="Twitter Influencer sentiment and BTC close price"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> Sentiment scores", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> BTC Close price", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="76acc1fc-621f-4318-8d72-54895a86c51d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76acc1fc-621f-4318-8d72-54895a86c51d")) {                    Plotly.newPlot(                        "76acc1fc-621f-4318-8d72-54895a86c51d",                        [{"line": {"color": "#00e600"}, "name": "BTC close price", "type": "scatter", "x": ["2018-01-18", "2018-01-19", "2018-01-20", "2018-01-22", "2018-01-24", "2018-01-28", "2018-02-01", "2018-02-02", "2018-02-03", "2018-02-05", "2018-02-06", "2018-02-07", "2018-02-08", "2018-02-10", "2018-02-11", "2018-02-13", "2018-02-14", "2018-02-19", "2018-02-22", "2018-02-28", "2018-03-01", "2018-03-03", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-12", "2018-03-18", "2018-03-20", "2018-03-22", "2018-03-23", "2018-03-30", "2018-03-31", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-09", "2018-04-10", "2018-04-11", "2018-04-12", "2018-04-14", "2018-04-16", "2018-04-18", "2018-04-21", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-29", "2018-05-01", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-15", "2018-05-19", "2018-05-20", "2018-05-21", "2018-05-23", "2018-05-26", "2018-05-27", "2018-05-29", "2018-05-31", "2018-06-02", "2018-06-06", "2018-06-08", "2018-06-10", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-17", "2018-06-18", "2018-06-19", "2018-06-20", "2018-06-21", "2018-06-22", "2018-06-23", "2018-06-26", "2018-06-28", "2018-07-03", "2018-07-04", "2018-07-06", "2018-07-07", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-14", "2018-07-15", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-20", "2018-07-21", "2018-07-22", "2018-07-23", "2018-07-24", "2018-07-26", "2018-07-27", "2018-07-28", "2018-07-29", "2018-07-30", "2018-07-31", "2018-08-02", "2018-08-03", "2018-08-04", "2018-08-06", "2018-08-08", "2018-08-10", "2018-08-11", "2018-08-12", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-18", "2018-08-19", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-26", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-09-01", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-09", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-14", "2018-09-16", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-23", "2018-09-24", "2018-09-25", "2018-09-26", "2018-09-28", "2018-09-29", "2018-10-04", "2018-10-05", "2018-10-06", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-14", "2018-10-16", "2018-10-17", "2018-10-21", "2018-10-22", "2018-10-23", "2018-10-24", "2018-10-25", "2018-10-31", "2018-11-01", "2018-11-02", "2018-11-04", "2018-11-08", "2018-11-11", "2018-11-13", "2018-11-14", "2018-11-15", "2018-11-20", "2018-11-22", "2018-11-25", "2018-11-26", "2018-11-27", "2018-12-03", "2018-12-04", "2018-12-05", "2018-12-06", "2018-12-10", "2018-12-12", "2018-12-14", "2018-12-15", "2018-12-16", "2018-12-18", "2018-12-19", "2018-12-21", "2018-12-22", "2018-12-23", "2018-12-24", "2018-12-25", "2018-12-29", "2018-12-30", "2019-01-03", "2019-01-05", "2019-01-06", "2019-01-07", "2019-01-08", "2019-01-10", "2019-01-11", "2019-01-14", "2019-01-17", "2019-01-18", "2019-01-20", "2019-01-24", "2019-01-25", "2019-01-28", "2019-02-02", "2019-02-03", "2019-02-04", "2019-02-05", "2019-02-07", "2019-02-08", "2019-02-10", "2019-02-11", "2019-02-12", "2019-02-13", "2019-02-14", "2019-02-17", "2019-02-20", "2019-02-23", "2019-02-25", "2019-02-26", "2019-02-28", "2019-03-01", "2019-03-03", "2019-03-05", "2019-03-07" ...

# %%
# Graph on News Sentiment against BTC price

import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces

fig.add_trace(
    go.Scatter(x=news_sentiment.Date, y=news_sentiment.Close, name="BTC close price",line=dict(color="#00e600")),
    secondary_y=True,
)

fig.add_trace(
    go.Scatter(x=news_sentiment.Date, y=news_sentiment.vader_compound, name="vader sentiment",line=dict(color="#e67300")),
    secondary_y=False,
)


fig.add_trace(
    go.Scatter(x=news_sentiment.Date, y=news_sentiment.textblob, name="textblob sentiment",line=dict(color="#ffbf80")),
    secondary_y=False,
)


# Add figure title
fig.update_layout(
    title_text="Twitter News sentiment and BTC close price"
)

# Set x-axis title
fig.update_xaxes(title_text="Date")

# Set y-axes titles
fig.update_yaxes(title_text="<b>primary</b> Sentiment scores", secondary_y=False)
fig.update_yaxes(title_text="<b>secondary</b> BTC Close price", secondary_y=True)

fig.show()
# Out:
# <div>                            <div id="25ea4ebd-492a-4044-9668-fbe567d82f37" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25ea4ebd-492a-4044-9668-fbe567d82f37")) {                    Plotly.newPlot(                        "25ea4ebd-492a-4044-9668-fbe567d82f37",                        [{"line": {"color": "#00e600"}, "name": "BTC close price", "type": "scatter", "x": ["2018-02-22", "2018-02-23", "2018-02-25", "2018-02-26", "2018-02-27", "2018-02-28", "2018-03-01", "2018-03-02", "2018-03-03", "2018-03-04", "2018-03-05", "2018-03-06", "2018-03-07", "2018-03-08", "2018-03-09", "2018-03-10", "2018-03-11", "2018-03-12", "2018-03-13", "2018-03-14", "2018-03-15", "2018-03-16", "2018-03-19", "2018-03-20", "2018-03-21", "2018-03-22", "2018-03-23", "2018-03-24", "2018-03-25", "2018-03-26", "2018-03-27", "2018-03-28", "2018-03-29", "2018-03-30", "2018-03-31", "2018-04-01", "2018-04-02", "2018-04-03", "2018-04-04", "2018-04-05", "2018-04-06", "2018-04-07", "2018-04-08", "2018-04-09", "2018-04-10", "2018-04-11", "2018-04-12", "2018-04-13", "2018-04-14", "2018-04-15", "2018-04-17", "2018-04-18", "2018-04-19", "2018-04-20", "2018-04-21", "2018-04-22", "2018-04-23", "2018-04-24", "2018-04-25", "2018-04-26", "2018-04-27", "2018-04-28", "2018-04-29", "2018-04-30", "2018-05-01", "2018-05-02", "2018-05-03", "2018-05-04", "2018-05-05", "2018-05-06", "2018-05-07", "2018-05-08", "2018-05-09", "2018-05-10", "2018-05-11", "2018-05-13", "2018-05-14", "2018-05-15", "2018-05-16", "2018-05-17", "2018-05-18", "2018-05-21", "2018-05-22", "2018-05-23", "2018-05-24", "2018-05-25", "2018-05-26", "2018-05-27", "2018-05-29", "2018-05-30", "2018-06-01", "2018-06-02", "2018-06-03", "2018-06-04", "2018-06-05", "2018-06-06", "2018-06-07", "2018-06-08", "2018-06-09", "2018-06-10", "2018-06-11", "2018-06-12", "2018-06-13", "2018-06-14", "2018-06-15", "2018-06-16", "2018-06-18", "2018-06-19", "2018-06-22", "2018-06-24", "2018-06-25", "2018-06-26", "2018-06-27", "2018-06-28", "2018-06-29", "2018-06-30", "2018-07-02", "2018-07-03", "2018-07-05", "2018-07-08", "2018-07-09", "2018-07-10", "2018-07-11", "2018-07-12", "2018-07-13", "2018-07-16", "2018-07-17", "2018-07-18", "2018-07-19", "2018-07-23", "2018-07-24", "2018-07-25", "2018-07-26", "2018-07-27", "2018-07-28", "2018-08-01", "2018-08-02", "2018-08-03", "2018-08-06", "2018-08-07", "2018-08-08", "2018-08-10", "2018-08-13", "2018-08-14", "2018-08-15", "2018-08-16", "2018-08-17", "2018-08-20", "2018-08-21", "2018-08-22", "2018-08-23", "2018-08-27", "2018-08-28", "2018-08-29", "2018-08-30", "2018-09-02", "2018-09-03", "2018-09-04", "2018-09-05", "2018-09-06", "2018-09-07", "2018-09-10", "2018-09-11", "2018-09-12", "2018-09-13", "2018-09-17", "2018-09-18", "2018-09-19", "2018-09-20", "2018-09-21", "2018-09-24", "2018-09-25", "2018-09-27", "2018-09-28", "2018-10-01", "2018-10-03", "2018-10-04", "2018-10-05", "2018-10-08", "2018-10-09", "2018-10-10", "2018-10-11", "2018-10-15", "2018-10-16", "2018-10-19", "2018-10-21", "2018-10-24", "2018-10-25", "2018-10-29", "2018-10-30", "2018-10-31", "2018-11-01", "2018-11-06", "2018-11-14", "2018-11-15", "2018-11-16", "2018-11-17", "2018-11-19", "2018-11-20", "2018-11-21", "2018-11-23", "2018-11-26", "2018-11-27", "2018-11-28", "2018-11-30", "2018-12-03", "2018-12-05", "2018-12-06", "2018-12-07", "2018-12-11", "2018-12-12", "2018-12-13", "2018-12-14", "2018-12-15", "2018-12-16", "2018-12-17", "2018-12-18", "2018-12-19", "2018-12-20", "2018-12-21", "2018-12-28", "2018-12-31", "2019-01-03", "2019-01-04", "2019-01-07", "2019-01-08", "2019-01-09", "2019-01-10", "2019-01-11", "2019-01-14", "2019-01-16", "2019-01-17", "2019-01-18", "2019-01-20", "2019-01-22", "2019-01-25", "2019-01-28", "2019-01-29", "2019-01-30", "2019-01-31", "2019-02-04", "2019-02-05" ...

# %%
#checking data with this filter

pd.options.display.max_colwidth = 500
news_sentiment[(news_sentiment['Date'] > '2018-03-18') & (news_sentiment['Date'] < '2018-03-21')]
# Out:
#           Date   Close  textblob  vader_compound  \
# 22  2018-03-19  8600.1   0.00000       -0.257733
# 23  2018-03-20  8899.7   0.07038        0.016577
#
#                                                                                                            text  \
# 22  Bitcoin has risen from a six-week low ahead of a G-20 meeting where officials will discuss digital assets
# 23                                                 Peter Thiel is bullish on Bitcoin, the heartland and Trump
#
#     tweet_id
# 22         3
# 23        13

# %%
# Reading in the results

influencer_results = pd.read_csv("inf_results.csv",index_col=[0])
news_results = pd.read_csv("news_results.csv",index_col=[0])

# %%
influencer_results
# Out:
#               corr_textblob  corr_vader  btc_twt_count  avg_textblob  \
# Charlie                0.13        0.01            453          0.15
# Roger                 -0.13       -0.05            497          0.14
# Andreas                0.11        0.07            690          0.15
# Pomp                  -0.16        0.10            491          0.18
# Vitalik                0.26        0.25            212          0.13
# Combined_inf           0.03        0.05           1640          0.15
#
#               avg_vader
# Charlie            0.23
# Roger              0.19
# Andreas            0.28
# Pomp               0.24
# Vitalik            0.21
# Combined_inf       0.22

# %%
fig_inf_results = px.bar(influencer_results, x=influencer_results.index, y=['corr_textblob','corr_vader'],barmode='group')
fig_inf_results.update_layout(title_text='Inflluencer Sentiment correlation to BTC price')
fig_inf_results.update_yaxes(tick0=-1, dtick=0.05)

fig_inf_results.show()
# Out:
# <div>                            <div id="fa982dcd-28ad-404d-8e14-10810793a673" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fa982dcd-28ad-404d-8e14-10810793a673")) {                    Plotly.newPlot(                        "fa982dcd-28ad-404d-8e14-10810793a673",                        [{"alignmentgroup": "True", "hovertemplate": "variable=corr_textblob<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "corr_textblob", "marker": {"color": "#636efa"}, "name": "corr_textblob", "offsetgroup": "corr_textblob", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Charlie", "Roger", "Andreas", "Pomp", "Vitalik", "Combined_inf"], "xaxis": "x", "y": [0.13, -0.13, 0.11, -0.16, 0.26, 0.03], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=corr_vader<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "corr_vader", "marker": {"color": "#EF553B"}, "name": "corr_vader", "offsetgroup": "corr_vader", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Charlie", "Roger", "Andreas", "Pomp", "Vitalik", "Combined_inf"], "xaxis": "x", "y": [0.01, -0.05, 0.07, 0.1, 0.25, 0.05], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2 ...

# %%
fig_news_results = px.bar(news_results, x=news_results.index, y=['corr_textblob','corr_vader'],barmode='group')
fig_news_results.update_layout(title_text='News Sentiment correlation to BTC price')
fig_news_results.show()
# Out:
# <div>                            <div id="77683134-3687-47bb-89ec-c9deac902a03" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("77683134-3687-47bb-89ec-c9deac902a03")) {                    Plotly.newPlot(                        "77683134-3687-47bb-89ec-c9deac902a03",                        [{"alignmentgroup": "True", "hovertemplate": "variable=corr_textblob<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "corr_textblob", "marker": {"color": "#636efa"}, "name": "corr_textblob", "offsetgroup": "corr_textblob", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Crypto", "Coin_Telegraph", "Coin_Desk", "Bitcoin", "BTCTN", "Combined_news"], "xaxis": "x", "y": [0.03, 0.18, -0.0, 0.02, 0.04, 0.04], "yaxis": "y"}, {"alignmentgroup": "True", "hovertemplate": "variable=corr_vader<br>index=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "corr_vader", "marker": {"color": "#EF553B"}, "name": "corr_vader", "offsetgroup": "corr_vader", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Crypto", "Coin_Telegraph", "Coin_Desk", "Bitcoin", "BTCTN", "Combined_news"], "xaxis": "x", "y": [0.1, 0.17, -0.03, 0.08, 0.07, 0.12], "yaxis": "y"}],                        {"barmode": "group", "legend": {"title": {"text": "variable"}, "tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"] ...
